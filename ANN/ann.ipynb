# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# reading the dataset

# %%
dataset=pd.read_csv('Churn_Modelling.csv')
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
X=dataset.iloc[:,3:-1].values
y=dataset.iloc[:,-1].values

# %%
print(X)
print(X.shape)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]
# (10000, 10)

# %%
print(y)
print(y.shape)
# Out:
# [1 0 1 ... 1 1 0]
# (10000,)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# label encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X[:,2]=le.fit_transform(X[:,2])
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %% [markdown]
# one hot encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[1])],remainder='passthrough')
X=np.array(ct.fit_transform(X))
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# feature scaling (compulsory for deep learning and applied for all features)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
print(X_train)
print(X_test)
# Out:
# [[-1.01460667 -0.5698444   1.74309049 ...  0.64259497 -1.03227043
#    1.10643166]
#  [-1.01460667  1.75486502 -0.57369368 ...  0.64259497  0.9687384
#   -0.74866447]
#  [ 0.98560362 -0.5698444  -0.57369368 ...  0.64259497 -1.03227043
#    1.48533467]
#  ...
#  [ 0.98560362 -0.5698444  -0.57369368 ...  0.64259497 -1.03227043
#    1.41231994]
#  [-1.01460667 -0.5698444   1.74309049 ...  0.64259497  0.9687384
#    0.84432121]
#  [-1.01460667  1.75486502 -0.57369368 ...  0.64259497 -1.03227043
#    0.32472465]]
# [[-1.01460667  1.75486502 -0.57369368 ...  0.64259497  0.9687384
#    1.61085707]
#  [ 0.98560362 -0.5698444  -0.57369368 ...  0.64259497 -1.03227043
#    0.49587037]
#  [-1.01460667 -0.5698444   1.74309049 ...  0.64259497  0.9687384
#   -0.42478674]
#  ...
#  [-1.01460667 -0.5698444   1.74309049 ...  0.64259497 -1.03227043
#    0.71888467]
#  [-1.01460667  1.75486502 -0.57369368 ...  0.64259497  0.9687384
#   -1.54507805]
# ...

# %% [markdown]
# ## Build ANN

# %% [markdown]
# init the ann

# %%
ann=tf.keras.models.Sequential()

# %% [markdown]
# adding the input(automatically initialised with neurons = no of features) layer and the first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# adding the second layer

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# adding the output layer

# %%
#if binary classification then sigmoid
#else softmax
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# ## Training the ANN

# %% [markdown]
# Comiling the ANN

# %%
#adam uses stochastic gradient descent to minimize the cost function
#if binary classification(i.e. o/p is 0 or 1) then use binary_crossentropy
#if non-binary classification then use categorical_crossentropy
ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Training the ANN

# %%
ann.fit(X_train, y_train, batch_size=32, epochs=1000)
# Out:
# Epoch 1/1000
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5182 - accuracy: 0.7960
# Epoch 2/1000
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7960
# Epoch 3/1000
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7960
# Epoch 4/1000
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4383 - accuracy: 0.7960
# Epoch 5/1000
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.7960
# Epoch 6/1000
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4304 - accuracy: 0.7960
# Epoch 7/1000
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4276 - accuracy: 0.8026
# Epoch 8/1000
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.8115
# Epoch 9/1000
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4235 - accuracy: 0.8180
# Epoch 10/1000
# ...

# %% [markdown]
# ## Prediction And Evaluation

# %% [markdown]
# **Homework**
#
# Use our ANN model to predict if the customer with the following informations will leave the bank:
#
# Geography: France
#
# Credit Score: 600
#
# Gender: Male
#
# Age: 40 years old
#
# Tenure: 3 years
#
# Balance: \$ 60000
#
# Number of Products: 2
#
# Does this customer have a credit card ? Yes
#
# Is this customer an Active Member: Yes
#
# Estimated Salary: \$ 50000
#
# So, should we say goodbye to that customer ?

# %%
ann.predict(sc.transform([[1,0,0,600,1,40,3,60000,2,1,1,50000]]))>0.5
# Out:
# 1/1 [==============================] - 0s 124ms/step
# array([[False]])

# %% [markdown]
# Prediction

# %%
y_pred=ann.predict(X_test)
y_pred=(y_pred>0.5)
print(y_pred)
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
print(accuracy_score(y_test,y_pred)*100)
# Out:
# [[1502   93]
#  [ 194  211]]
# 85.65
